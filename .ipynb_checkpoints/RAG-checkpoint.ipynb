# %%
# !pip install langchain

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 28.4 MB/s eta 0:00:00
# ...

# %%
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 MB 21.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 16.5 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 18.4 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 18.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# ...

# %%
# !pip install pandas

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# %%
df = pd.read_csv("matches.csv")

# %%
df
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1      2    2017       Pune  6/4/2017               Mumbai Indians
# 2      3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3      4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.drop('umpire3',axis=1)
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1      2    2017       Pune  6/4/2017               Mumbai Indians
# 2      3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3      4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.shape
# Out:
# (636, 18)

# %%
df = df.drop('umpire3',axis=1)

# %%
df = df.drop('id',axis=1)

# %%
df
# Out:
#      Unnamed: 0  season       city      date                        team1  \
# 0             0    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1             1    2017       Pune  6/4/2017               Mumbai Indians
# 2             2    2017     Rajkot  7/4/2017                Gujarat Lions
# 3             3    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4             4    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
# ..          ...     ...        ...       ...                          ...
# 631         631    2016     Raipur  22/05/16             Delhi Daredevils
# 632         632    2016  Bangalore  24/05/16                Gujarat Lions
# 633         633    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634         634    2016      Delhi  27/05/16                Gujarat Lions
# 635         635    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# combined_text      0
# dtype: int64

# %%
columns_to_fill = ["umpire1", "umpire2", "player_of_match", "winner", "city"]
df[columns_to_fill] = df[columns_to_fill].fillna("The field is not available")

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# combined_text      0
# dtype: int64

# %%
df.to_csv('Cleaned_data.csv')

# %%
df = pd.read_csv('Cleaned_data.csv')

# %%
def row_to_text(row):
    text = (
        f"Season: {row['season']}, City: {row['city']}, Date: {row['date']}, "
        f"Team 1: {row['team1']}, Team 2: {row['team2']}, Toss Winner: {row['toss_winner']}, "
        f"Toss Decision: {row['toss_decision']}, Result: {row['result']}, DL Applied: {row['dl_applied']}, "
        f"Winner: {row['winner']}, Win by Runs: {row['win_by_runs']}, Win by Wickets: {row['win_by_wickets']}, "
        f"Player of the Match: {row['player_of_match']}, Venue: {row['venue']}, Umpire 1: {row['umpire1']}, "
        f"Umpire 2: {row['umpire2']}"
    )
    return text

# %%
df['combined_text'] = df.apply(row_to_text, axis=1)

# %%
df['combined_text']
# Out:
# 0      Season: 2017, City: Hyderabad, Date: 5/4/2017,...
# 1      Season: 2017, City: Pune, Date: 6/4/2017, Team...
# 2      Season: 2017, City: Rajkot, Date: 7/4/2017, Te...
# 3      Season: 2017, City: Indore, Date: 8/4/2017, Te...
# 4      Season: 2017, City: Bangalore, Date: 8/4/2017,...
#                              ...
# 631    Season: 2016, City: Raipur, Date: 22/05/16, Te...
# 632    Season: 2016, City: Bangalore, Date: 24/05/16,...
# 633    Season: 2016, City: Delhi, Date: 25/05/16, Tea...
# 634    Season: 2016, City: Delhi, Date: 27/05/16, Tea...
# 635    Season: 2016, City: Bangalore, Date: 29/05/16,...
# Name: combined_text, Length: 636, dtype: object

# %%
df['combined_text'].to_csv('textdata.txt',index=False,header=False)

# %%
file_path = "textdata.txt"
with open(file_path, "r") as file:
    content = file.read()
content = content.replace('"', '')
with open(file_path, "w") as file:
    file.write(content)

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFaceHub
from langchain.text_splitter import CharacterTextSplitter
from langchain_ollama import OllamaLLM
from langchain.chains import LLMChain

# %%
# Read and preprocess the text file
with open("textdata.txt", "r") as file:
    raw_text = file.read()

# Split the text based on `Match ID` occurrences
preprocessed_text = raw_text.replace("Season:", "\nSeason:")

# Save the preprocessed text to a new file
with open("textdata.txt", "w") as file:
    file.write(preprocessed_text)

# %%
# Read and preprocess the text file
with open("textdata.txt", "r") as file:
    text = file.read()

# %%
text_splitter = CharacterTextSplitter(
    chunk_size=500,  
    chunk_overlap=50
)
text_chunks = text_splitter.split_text(text)

# %%
# Verify the text splitting process
text_chunks = text_splitter.split_text(text)

print(f"Number of chunks created: {len(text_chunks)}")
for i, chunk in enumerate(text_chunks[:5]):  # Display the first 5 chunks
    print(f"Chunk {i+1}:\n{chunk}\n{'-'*50}")
# Out:
# Number of chunks created: 636
# Chunk 1:
# Season: 2017, City: Hyderabad, Date: 5/4/2017, Team 1: Sunrisers Hyderabad, Team 2: Royal Challengers Bangalore, Toss Winner: Royal Challengers Bangalore, Toss Decision: field, Result: normal, DL Applied: 0, Winner: Sunrisers Hyderabad, Win by Runs: 35, Win by Wickets: 0, Player of the Match: Yuvraj Singh, Venue: Rajiv Gandhi International Stadium, Uppal, Umpire 1: AY Dandekar, Umpire 2: NJ Llong
# --------------------------------------------------
# Chunk 2:
# Season: 2017, City: Pune, Date: 6/4/2017, Team 1: Mumbai Indians, Team 2: Rising Pune Supergiant, Toss Winner: Rising Pune Supergiant, Toss Decision: field, Result: normal, DL Applied: 0, Winner: Rising Pune Supergiant, Win by Runs: 0, Win by Wickets: 7, Player of the Match: SPD Smith, Venue: Maharashtra Cricket Association Stadium, Umpire 1: A Nand Kishore, Umpire 2: S Ravi
# --------------------------------------------------
# Chunk 3:
# ...

# %%
embeddings_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
faiss_index = FAISS.from_texts(texts=text_chunks, embedding=embeddings_model)

# %%
prompt_template = """
You are a highly intelligent assistant. Use the provided context to answer the question efficiently.
The date in the provided context is of the form DD/MM/YYYY .
Team 1 and Team2 denotes that the match happened between Team 1 and Team 2 .
If the query contains CSK , Each letter stands for the abbreviation of a word , like CSK equals Chennai super kings and so on .
If the context does not contain the specific answer pertaining to the question, Dont provide a random answer

Context:
{context}

Question:
{question}

Answer:
"""

prompt = PromptTemplate(input_variables=["context", "question"], template=prompt_template)

# %%
retriever = faiss_index.as_retriever()

# %%
llm = OllamaLLM(base_url="http://localhost:11434", model="phi3")

# %%
def answer_with_context(query):
    retriever = faiss_index.as_retriever(search_type="similarity", search_kwargs={"k": 10})
    docs = retriever.get_relevant_documents(query)
    context = "\n".join([doc.page_content for doc in docs])
    chain = LLMChain(llm=llm, prompt=prompt)
    response = chain.run({"context": context, "question": query})
    return response, context

# %%
qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=retriever)

# %%
questions = [
    "1. Which two teams played an IPL match on the 5th of April 2017 ?",
    "2. Who won the toss during the match that happened on the 7th of April 2017 ?",
    "3. Who won the match between KKR and RR that happened on 20/05/08 ?",
    "4.  How many matches happened on the 9th of April 2017 ?",
    "5. In what locations did KKR and CSK play a match in the year 2010 ?",
    "6. What was the highest margin of victory (by runs) achieved in matches played at Wankhede Stadium in 2017?",
    "7. How many matches did MI play against CSK in the 2017 season, and what were the results?",
    "8. Who were the umpires for the match where the team batting second won by the smallest margin in 2017?",
    "9. Which team had the most wins in matches played at Eden Gardens across all seasons?",
    "10 . What was the total number of no-results (matches without a winner) in IPL history up to the 2017 season?",
]

# %%
for i in questions : 
    response, context = answer_with_context(i)
    print("\nQuery:", i)
    print("\nRetrieved Context:\n", context)
    print("\nGenerated Response:\n", response)
# Out:
# Query: 1. Which two teams played an IPL match on the 5th of April 2017 ?
#
# Retrieved Context:
#  Season: 2017, City: Hyderabad, Date: 9/4/2017, Team 1: Gujarat Lions, Team 2: Sunrisers Hyderabad, Toss Winner: Sunrisers Hyderabad, Toss Decision: field, Result: normal, DL Applied: 0, Winner: Sunrisers Hyderabad, Win by Runs: 0, Win by Wickets: 9, Player of the Match: Rashid Khan, Venue: Rajiv Gandhi International Stadium, Uppal, Umpire 1: A Deshmukh, Umpire 2: NJ Llong
# Season: 2017, City: Hyderabad, Date: 5/4/2017, Team 1: Sunrisers Hyderabad, Team 2: Royal Challengers Bangalore, Toss Winner: Royal Challengers Bangalore, Toss Decision: field, Result: normal, DL Applied: 0, Winner: Sunrisers Hyderabad, Win by Runs: 35, Win by Wickets: 0, Player of the Match: Yuvraj Singh, Venue: Rajiv Gandhi International Stadium, Uppal, Umpire 1: AY Dandekar, Umpire 2: NJ Llong
# ...
